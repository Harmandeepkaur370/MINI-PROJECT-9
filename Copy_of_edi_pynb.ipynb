# %% [markdown]
# <a href="https://colab.research.google.com/github/Harmandeepkaur370/MINI-PROJECT-9/blob/main/Copy_of_edi_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MINI PROJECT -09**
# select any dataset from uci dataset repository and perform EDA[ exploratory data analysis).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/winequality-red.csv', delimiter=";") # delimiter(sperartor) between values is semicolon
print("first five rows:")
df.head(5)
# Out:
# first five rows:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# ...

# %%
print("last five rows:")
df.tail(5)
# Out:
# last five rows:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# ...

# %%
print("column info:")
df.info()
# Out:
# column info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
print("shape of dataset:", df.shape)
print(df.columns)
print(df.keys())
# Out:
# shape of dataset: (1599, 12)
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
print("summary stats:")
print(df.describe())
# Out:
# summary stats:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
pd.unique(df['quality'])
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df= df.drop(["alcohol","chlorides"], axis=1) # dropping irrelevent columns
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0            7.4              0.70         0.00             1.9
# 1            7.8              0.88         0.00             2.6
# 2            7.8              0.76         0.04             2.3
# 3           11.2              0.28         0.56             1.9
# 4            7.4              0.70         0.00             1.9
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
# renaming columns
df= df.rename(columns={'fixed acidity':'fixed_acidity', 'volatile acidity':'volatile_acidity', 'citric acid':'citric_acid', 'residual sugar':'residual_sugar', 'free sulfur dioxide':'free_sulfur_dioxide', 'total sulfur dioxide':'total_sulfur_dioxide'})
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0            7.4              0.70         0.00             1.9
# 1            7.8              0.88         0.00             2.6
# 2            7.8              0.76         0.04             2.3
# 3           11.2              0.28         0.56             1.9
# 4            7.4              0.70         0.00             1.9
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
# dropping duplicate rows
print(df.shape)
duplicate_rows= df[df.duplicated()]
print("number of duplicate rows:", len(duplicate_rows))
print(df.head(2))
print("after deleting duplicate rows the shape of df is:",df.shape)
# Out:
# (1599, 10)
# number of duplicate rows: 244
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0            7.4              0.70          0.0             1.9
# 1            7.8              0.88          0.0             2.6
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    quality
# 0        5
# 1        5
# after deleting duplicate rows the shape of df is: (1599, 10)

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0            7.4              0.70         0.00             1.9
# 1            7.8              0.88         0.00             2.6
# 2            7.8              0.76         0.04             2.3
# 3           11.2              0.28         0.56             1.9
# 5            7.4              0.66         0.00             1.8
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 5        5

# %%
df.count()
# Out:
# fixed_acidity           1355
# volatile_acidity        1355
# citric_acid             1355
# residual_sugar          1355
# free_sulfur_dioxide     1355
# total_sulfur_dioxide    1355
# density                 1355
# pH                      1355
# sulphates               1355
# quality                 1355
# dtype: int64

# %%
# dropping the missing or null values
print(df.isnull().sum())
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# quality                 0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# fixed_acidity           1355
# volatile_acidity        1355
# citric_acid             1355
# residual_sugar          1355
# free_sulfur_dioxide     1355
# total_sulfur_dioxide    1355
# density                 1355
# pH                      1355
# sulphates               1355
# quality                 1355
# dtype: int64

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# quality                 0
# dtype: int64

# %%
sns.boxplot(x=df['quality'])
# Out:
# <Axes: xlabel='quality'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['pH'])
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['density'], y=df['quality'])
plt.title("scatter plot between density and quality")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['citric_acid'],y=df['sulphates'])
plt.title(" line plot between citric_acid and sulphates")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation Heatmap")
plt.show()
